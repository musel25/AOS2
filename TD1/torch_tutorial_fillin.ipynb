# %% [markdown]
# # Introduction to Pytorch

# %% [markdown]
# ## Introduction to autodiff

# %% [markdown]
# ### Autodiff for simple gradient descent

# %% [markdown]
# Load needed libraries
# $\newcommand\p[1]{{\left(#1\right)}}$
# $\newcommand\code[1]{\texttt{#1}}$

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.optim as optim

# %% [markdown]
# Here is a simple example of how to find the minimum of the function
# $x\mapsto\p{x-3}^2$ using the autodiff functionality of Pytorch.
#
# First initialize a tensor `x` and indicate that we want to store a
# gradient on it.

# %%
x = torch.tensor([1.0], requires_grad=True)

# %% [markdown]
# Create an optimizer on parameters. Here we want to optimize w.r.t.
# variable `x`:

# %%
optimizer = optim.SGD([x], lr=0.01)

# %% [markdown]
# Create a computational graph using parameters (here only `x`) and
# potentially other tensors.
#
# Here we only want to compute $\p{x-3}^2$ so we define:

# %%
y = (x - 3) ** 2

# %% [markdown]
# Back-propagating gradients for `y` down to `x`. Don't forget to
# reset gradients before.

# %%
optimizer.zero_grad()

# %%
optimizer.zero_grad()
y.backward()

# %% [markdown]
# Use gradient on `x` to apply a one-step gradient descent.

# %%
optimizer.step()
x.grad
x
# Out:
# tensor([1.0400], requires_grad=True)

# %% [markdown]
# And last we iterate the whole process

# %%
it = 0
while it < 1000:
    loss = (x - 3) ** 2
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if it % 20 == 0:
        print('Iteration: %d, x: %f, loss: %f' % (it, x.item(), loss.item()))
    it += 1
# Out:
# Iteration: 0, x: 1.079200, loss: 3.841600
# Iteration: 20, x: 1.717659, loss: 1.712203
# Iteration: 40, x: 2.143898, loss: 0.763130
# Iteration: 60, x: 2.428460, loss: 0.340127
# Iteration: 80, x: 2.618435, loss: 0.151595
# Iteration: 100, x: 2.745265, loss: 0.067566
# Iteration: 120, x: 2.829937, loss: 0.030114
# Iteration: 140, x: 2.886464, loss: 0.013422
# Iteration: 160, x: 2.924203, loss: 0.005982
# Iteration: 180, x: 2.949397, loss: 0.002666
# Iteration: 200, x: 2.966216, loss: 0.001188
# Iteration: 220, x: 2.977446, loss: 0.000530
# Iteration: 240, x: 2.984942, loss: 0.000236
# Iteration: 260, x: 2.989947, loss: 0.000105
# Iteration: 280, x: 2.993288, loss: 0.000047
# Iteration: 300, x: 2.995519, loss: 0.000021
# Iteration: 320, x: 2.997009, loss: 0.000009
# Iteration: 340, x: 2.998003, loss: 0.000004
# Iteration: 360, x: 2.998666, loss: 0.000002
# Iteration: 380, x: 2.999109, loss: 0.000001
# Iteration: 400, x: 2.999405, loss: 0.000000
# Iteration: 420, x: 2.999603, loss: 0.000000
# Iteration: 440, x: 2.999735, loss: 0.000000
# Iteration: 460, x: 2.999823, loss: 0.000000
# Iteration: 480, x: 2.999882, loss: 0.000000
# Iteration: 500, x: 2.999921, loss: 0.000000
# Iteration: 520, x: 2.999947, loss: 0.000000
# Iteration: 540, x: 2.999964, loss: 0.000000
# Iteration: 560, x: 2.999976, loss: 0.000000
# Iteration: 580, x: 2.999984, loss: 0.000000
# Iteration: 600, x: 2.999989, loss: 0.000000
# Iteration: 620, x: 2.999993, loss: 0.000000
# Iteration: 640, x: 2.999994, loss: 0.000000
# Iteration: 660, x: 2.999994, loss: 0.000000
# Iteration: 680, x: 2.999994, loss: 0.000000
# Iteration: 700, x: 2.999994, loss: 0.000000
# Iteration: 720, x: 2.999994, loss: 0.000000
# Iteration: 740, x: 2.999994, loss: 0.000000
# Iteration: 760, x: 2.999994, loss: 0.000000
# Iteration: 780, x: 2.999994, loss: 0.000000
# Iteration: 800, x: 2.999994, loss: 0.000000
# Iteration: 820, x: 2.999994, loss: 0.000000
# Iteration: 840, x: 2.999994, loss: 0.000000
# Iteration: 860, x: 2.999994, loss: 0.000000
# Iteration: 880, x: 2.999994, loss: 0.000000
# Iteration: 900, x: 2.999994, loss: 0.000000
# Iteration: 920, x: 2.999994, loss: 0.000000
# Iteration: 940, x: 2.999994, loss: 0.000000
# Iteration: 960, x: 2.999994, loss: 0.000000
# Iteration: 980, x: 2.999994, loss: 0.000000

# %% [markdown]
# ### Differentiate the exponential
#
# The exponential function can be approximated using its Taylor
# expansion:
# $$
# \exp\p{z}\approx\sum_{k=0}^{N}\frac{z^k}{k!}
# $$
#
# First define `x`, the "parameter" and build a computational graph from
# it to compute the exponential.

# %%
x = torch.tensor([1.0], requires_grad=True)
optimizer = optim.SGD([x], lr=0.01)

# %% [markdown]
# Compute the gradient and verify that it is correct

# %%
def exponential(x):
    N = 20
    exp = 0
    it = 0
    fact = 1
    while it < N:
        exp += x ** it / fact
        it += 1
        fact *= it
    return exp

exp = exponential(x)
optimizer.zero_grad()

exp.backward()
x.grad
# Out:
# tensor([2.7183])

# %% [markdown]
# ### Solving equations with Pytorch
#
# Suppose we want to solve the following system of two equations
# $$
# e^{-e^{-(x_1 + x_2)}} = x_2 (1 + x_1^2)
# $$
# $$
# x_1 \cos(x_2) + x_2 \sin(x_1) = 1/2
# $$
#
# Find a loss whose optimization leads to a solution of the system of
# equations above.

# %%
def t(x,y):
    return y-2*x-1

t(3,5)
# Out:
# -2

# %%
def f1(x1, x2):
    a = torch.exp(-torch.exp(-(x1 + x2)))
    b = x2 * (1 + x1 **2)
    return  a-b

def f2(x1,  x2):
    a= x1 * torch.cos(x2) + x2 * torch.sin(x1)
    b = 1/2
    return a-b

# %%
x1 = torch.tensor([0.0], requires_grad=True)
x2 = torch.tensor([0.0], requires_grad=True)

# %% [markdown]
# Use Pytorch autodiff to solve the system of equations

# %%
optimizer = optim.SGD([x1, x2], lr = 0.01)

it = 0
while it < 1000:
    loss =  f1(x1, x2)**2 + f2(x1, x2)** 2
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if it % 20 == 0:
        print('Iteration: %d, x1: %f, x2: %f, loss: %f' % (it, x1.item(), x2.item(), loss.item()))
    it += 1

f1(x1, x2).item(), f2(x1, x2).item()
# Out:
# Iteration: 0, x1: 0.007293, x2: 0.004651, loss: 0.385335
# Iteration: 20, x1: 0.134238, x2: 0.107664, loss: 0.250012
# Iteration: 40, x1: 0.229074, x2: 0.214341, loss: 0.146439
# Iteration: 60, x1: 0.294770, x2: 0.309024, loss: 0.078318
# Iteration: 80, x1: 0.335219, x2: 0.384967, loss: 0.040020
# Iteration: 100, x1: 0.356608, x2: 0.442270, loss: 0.020582
# Iteration: 120, x1: 0.365716, x2: 0.484327, loss: 0.010968
# Iteration: 140, x1: 0.368040, x2: 0.515040, loss: 0.006060
# Iteration: 160, x1: 0.367179, x2: 0.537610, loss: 0.003429
# Iteration: 180, x1: 0.365141, x2: 0.554350, loss: 0.001966
# Iteration: 200, x1: 0.362903, x2: 0.566874, loss: 0.001134
# Iteration: 220, x1: 0.360872, x2: 0.576303, loss: 0.000656
# Iteration: 240, x1: 0.359175, x2: 0.583435, loss: 0.000380
# Iteration: 260, x1: 0.357814, x2: 0.588844, loss: 0.000221
# Iteration: 280, x1: 0.356749, x2: 0.592954, loss: 0.000128
# Iteration: 300, x1: 0.355924, x2: 0.596081, loss: 0.000074
# Iteration: 320, x1: 0.355290, x2: 0.598461, loss: 0.000043
# Iteration: 340, x1: 0.354805, x2: 0.600274, loss: 0.000025
# Iteration: 360, x1: 0.354435, x2: 0.601656, loss: 0.000015
# Iteration: 380, x1: 0.354152, x2: 0.602708, loss: 0.000008
# Iteration: 400, x1: 0.353937, x2: 0.603511, loss: 0.000005
# Iteration: 420, x1: 0.353773, x2: 0.604122, loss: 0.000003
# Iteration: 440, x1: 0.353648, x2: 0.604588, loss: 0.000002
# Iteration: 460, x1: 0.353552, x2: 0.604943, loss: 0.000001
# Iteration: 480, x1: 0.353480, x2: 0.605214, loss: 0.000001
# Iteration: 500, x1: 0.353424, x2: 0.605420, loss: 0.000000
# Iteration: 520, x1: 0.353382, x2: 0.605577, loss: 0.000000
# Iteration: 540, x1: 0.353350, x2: 0.605697, loss: 0.000000
# Iteration: 560, x1: 0.353325, x2: 0.605789, loss: 0.000000
# Iteration: 580, x1: 0.353307, x2: 0.605858, loss: 0.000000
# Iteration: 600, x1: 0.353292, x2: 0.605912, loss: 0.000000
# Iteration: 620, x1: 0.353281, x2: 0.605952, loss: 0.000000
# Iteration: 640, x1: 0.353273, x2: 0.605983, loss: 0.000000
# Iteration: 660, x1: 0.353267, x2: 0.606006, loss: 0.000000
# Iteration: 680, x1: 0.353262, x2: 0.606024, loss: 0.000000
# Iteration: 700, x1: 0.353258, x2: 0.606038, loss: 0.000000
# Iteration: 720, x1: 0.353256, x2: 0.606048, loss: 0.000000
# Iteration: 740, x1: 0.353254, x2: 0.606056, loss: 0.000000
# Iteration: 760, x1: 0.353252, x2: 0.606062, loss: 0.000000
# Iteration: 780, x1: 0.353251, x2: 0.606067, loss: 0.000000
# Iteration: 800, x1: 0.353250, x2: 0.606071, loss: 0.000000
# Iteration: 820, x1: 0.353249, x2: 0.606073, loss: 0.000000
# Iteration: 840, x1: 0.353249, x2: 0.606075, loss: 0.000000
# Iteration: 860, x1: 0.353248, x2: 0.606076, loss: 0.000000
# Iteration: 880, x1: 0.353248, x2: 0.606078, loss: 0.000000
# Iteration: 900, x1: 0.353248, x2: 0.606079, loss: 0.000000
# Iteration: 920, x1: 0.353247, x2: 0.606079, loss: 0.000000
# Iteration: 940, x1: 0.353247, x2: 0.606079, loss: 0.000000
# Iteration: 960, x1: 0.353247, x2: 0.606079, loss: 0.000000
# Iteration: 980, x1: 0.353247, x2: 0.606079, loss: 0.000000
# (1.7881393432617188e-06, 7.152557373046875e-07)

# %% [markdown]
# ## Linear least squares in Pytorch

# %% [markdown]
# ### Synthetic data
#
# We use the following linear model:
#
# $$
# y = \langle\beta,x\rangle+\varepsilon
# $$
#
# where $x\in\mathcal R^p$ and $\varepsilon\sim\mathcal N(0, \sigma^2)$.

# %%
import math
p = 512
N = 50000
X = torch.randn(N, p)
beta = torch.randn(p, 1) / math.sqrt(p)
y = torch.mm(X, beta) + 0.5 * torch.randn(N, 1)

# %% [markdown]
# ### Model implementation
#
# Every model in Pytorch is implemented as a class that derives from
# `nn.Module`. The two main methods to implement are:
#
# -   `__init__`: Declare needed building blocks to implement forward pass
# -   `forward`: Implement the forward pass from the input given as
#     argument

# %%
import torch.nn as nn

class LinearLeastSquare(nn.Module):
    def __init__(self, input_size):
        super(LinearLeastSquare, self).__init__()

        # Declaring neural networks building blocks. Here we only need
        # a linear transform.
        self.linear = nn.Linear(input_size, 1)

    def forward(self, input):
        # Implementing forward pass. Return corresponding output for
        # this neural network.
        return self.linear(input)

# %% [markdown]
# ### Preparing dataset

# %%
from torch.utils.data import TensorDataset

# Gather data coming from Pytorch tensors using `TensorDataset`
dataset = TensorDataset(X, y)

from torch.utils.data import DataLoader
# Define `train_loader` that is an iterable on mini-batches using
# `DataLoader`
batch_size = 128
train_loader = DataLoader(dataset, batch_size, shuffle=True)

# Loss function to use
from torch.nn import MSELoss
loss_fn = MSELoss()

# Optimization algorithm
from torch.optim import SGD

# Instantiate model with `LinearLeastSquare` with the correct input
# size.
model = LinearLeastSquare(input_size=p)

# Use the stochastic gradient descent algorithm with a learning rate of
# 0.01 and a momentum of 0.9.
optimizer = SGD(model.parameters(), lr = 0.01, momentum=0.9)

# %% [markdown]
# ## Learning loop

# %%
# Inspect DataLoader "shape"-like info
num_batches = len(train_loader)
num_samples = len(train_loader.dataset)

# Get shape of one batch (first batch)
src_batch, tgt_batch = next(iter(train_loader))
src_shape = src_batch.shape
tgt_shape = tgt_batch.shape

print(f"num_batches: {num_batches}")
print(f"num_samples: {num_samples}")
print(f"src batch shape: {src_shape}")
print(f"tgt batch shape: {tgt_shape}")
# Out:
# num_batches: 391
# num_samples: 50000
# src batch shape: torch.Size([128, 512])
# tgt batch shape: torch.Size([128, 1])

# %%
optimizer.zero_grad()
# Forward pass
outputs = model.forward(X)

# Backpropagation on loss
loss = loss_fn(outputs, y)
loss.backward()

# Gradient descent step
optimizer.step()


print(f"Last loss: {loss}")
# Out:
# Last loss: 0.4180588722229004

# %%
epochs = 10
losses = []
for i in range(epochs):
    for src, tgt in train_loader:
        # Forward pass
        # outputs = model.forward(src)
        outputs = model(src)
        # Backpropagation on loss
        loss = loss_fn(outputs, tgt)
        optimizer.zero_grad()
        loss.backward()

        # Gradient descent step
        optimizer.step()

        losses.append(loss.item())

    print(f"Epoch {i}/{epochs}: Last loss: {loss}")

x = np.arange(len(losses)) / len(losses) * epochs
plt.plot(x, losses)
# Out:
# Epoch 0/10: Last loss: 0.4473094940185547
# Epoch 1/10: Last loss: 0.45529237389564514
# Epoch 2/10: Last loss: 0.387440025806427
# Epoch 3/10: Last loss: 0.4638792872428894
# Epoch 4/10: Last loss: 0.3825545907020569
# Epoch 5/10: Last loss: 0.3692284822463989
# Epoch 6/10: Last loss: 0.33960798382759094
# Epoch 7/10: Last loss: 0.452923059463501
# Epoch 8/10: Last loss: 0.38751354813575745
# Epoch 9/10: Last loss: 0.3160903751850128

# %% [markdown]
# From the model what should be the minimum MSE?
# &#x2026;

# %% [markdown]
# ## Learning loop with scheduler
#
# From convex optimization theory the learning rate should be decreasing
# toward 0. To have something approaching we use a scheduler that is
# updating the learning rate every epoch.

# %%
from torch.optim.lr_scheduler import MultiStepLR

# Define a scheduler
losses = []
model = LinearLeastSquare(p)
optimizer = SGD(model.parameters(), lr = 0.01, momentum=0.9)
scheduler = MultiStepLR(optimizer, milestones=[3, 6])

# Implement the learning loop with a scheduler
for i in range(epochs):
    for src, tgt in train_loader:
        optimizer.zero_grad()

        outputs = model.forward(src)
        loss = loss_fn(outputs, tgt)
        loss.backward()

        optimizer.step()
        losses.append(loss.item())
    scheduler.step()

    print(f"Epoch {i}/{epochs}: Last loss: {loss}")

x = np.arange(len(losses)) / len(losses) * epochs
plt.plot(x, losses)
# Out:
# Epoch 0/10: Last loss: 0.47112423181533813
# Epoch 1/10: Last loss: 0.3827851414680481
# Epoch 2/10: Last loss: 0.4524577558040619
# Epoch 3/10: Last loss: 0.2566271722316742
# Epoch 4/10: Last loss: 0.2784504294395447
# Epoch 5/10: Last loss: 0.3701293468475342
# Epoch 6/10: Last loss: 0.21383118629455566
# Epoch 7/10: Last loss: 0.222081258893013
# Epoch 8/10: Last loss: 0.2571926712989807
# Epoch 9/10: Last loss: 0.23779670894145966

# %% [markdown]
# ## Multi-layer perceptron
#
# Implement a multi-layer perceptron described by the following
# function:
# $$
# f\p{x,\beta}=W_3\sigma\p{W_2\sigma{W_1 x}}
# $$
# where $\sigma\p{x}=\max\p{x, 0}$

# %%
class MultiLayerPerceptron(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size):
        super(MultiLayerPerceptron, self).__init__()

        # Define hyperparameters of neural network and building blocks
        self.input_size = input_size
        self.hidden_size1 = hidden_size1
        self.hidden_size2 = hidden_size2
        self.output_size = output_size

        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.fc3 = nn.Linear(hidden_size2, output_size)

    def forward(self, x):
        # Implement forward pass
        output = torch.relu(self.fc1(x))
        output = torch.relu(self.fc2(output))
        output = torch.sigmoid(self.fc3(output))
        return output

# %%
### Synthetic 2-dimensional spiral dataset

n_classes = 3
n_loops = 2
n_samples = 1500

def spirals(n_classes=3, n_samples=1500, n_loops=2):
    klass = np.random.choice(n_classes, n_samples)
    radius = np.random.rand(n_samples)
    theta = klass * 2 * math.pi / n_classes + radius * 2 * math.pi * n_loops
    radius = radius + 0.05 * np.random.randn(n_samples)
    return np.column_stack((radius * np.cos(theta), radius * np.sin(theta))).astype("float32"), klass

X_, y_ = spirals(n_samples=n_samples, n_classes=n_classes, n_loops=n_loops)
plt.scatter(X_[:, 0], X_[:, 1], c=y_)

# %% [markdown]
# ### Preparing dataset

# %%
from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

X = torch.from_numpy(X_)
y = torch.from_numpy(y_)
dataset = TensorDataset(X, y)
batch_size = 32
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

X_, y_ = spirals(n_samples=1000, n_classes=n_classes, n_loops=n_loops)
X = torch.from_numpy(X_)
y = torch.from_numpy(y_)
test_set = TensorDataset(X, y)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### The learning loop

# %%
from torch.optim import SGD, Adam
from torch.nn import CrossEntropyLoss

loss_fn = CrossEntropyLoss()
model = MultiLayerPerceptron(2, 20, 20, n_classes)
optimizer = SGD(model.parameters(), lr=0.05)
optimizer = Adam(model.parameters())

import copy

epochs = 1000
losses = []
models = []
for i in range(epochs):
    for src, tgt in train_loader:
        optimizer.zero_grad()

        outputs = model.forward(src)

        loss = loss_fn(outputs, tgt.long())
        loss.backward()

        optimizer.step()
        losses.append(loss.item())

    # Accuracy on the test set
    acc = 0.
    for src, tgt in test_loader:
        prd = model(src).detach().argmax(dim=1)
        acc += sum(prd == tgt).item()

    acc /= len(test_set)
    print(f"Epoch {i}/{epochs}: Test accuracy: {acc}")

    models.append(copy.deepcopy(model))


def get_image_data(model, colors, xs, ys):
    """Return color image of size H*W*4."""

    # Generate points in grid
    xx, yy = np.meshgrid(xs, ys)
    points = np.column_stack((xx.ravel(), yy.ravel())).astype("float32")
    points = torch.from_numpy(points)

    # Predict class probability on points
    prd = model(points).detach()
    prd = torch.nn.functional.softmax(prd, dim=1)

    # Build a color image from colors
    colors = torch.from_numpy(colors)
    img = torch.mm(prd, colors).numpy()
    img = img.reshape((ynum, xnum, 4))
    img = np.minimum(img, 1)

    return img

fig, ax = plt.subplots()

# Get n_classes colors in RGBa form
prop_cycle = plt.rcParams["axes.prop_cycle"]
colors = prop_cycle.by_key()["color"]
import matplotlib as mpl
colors = mpl.colors.to_rgba_array(colors)[:n_classes, :4].astype("float32")

# Draw scatter plot of test set using colors
ax.scatter(X[:, 0], X[:, 1], c=colors[y])
xmin, xmax = ax.get_xlim()
ymin, ymax = ax.get_ylim()
xnum, ynum = (int(i) for i in fig.dpi * fig.get_size_inches())

# Create discretization
xs = np.linspace(xmin, xmax, xnum)
ys = np.linspace(ymin, ymax, ynum)
img = get_image_data(model, colors, xs, ys)

ax.imshow(img, extent=[xmin, xmax, ymin, ymax], origin="lower", alpha=.7)
# Out:
# Epoch 0/1000: Test accuracy: 0.344
# Epoch 1/1000: Test accuracy: 0.373
# Epoch 2/1000: Test accuracy: 0.364
# Epoch 3/1000: Test accuracy: 0.376
# Epoch 4/1000: Test accuracy: 0.379
# Epoch 5/1000: Test accuracy: 0.387
# Epoch 6/1000: Test accuracy: 0.383
# Epoch 7/1000: Test accuracy: 0.382
# Epoch 8/1000: Test accuracy: 0.392
# Epoch 9/1000: Test accuracy: 0.395
# Epoch 10/1000: Test accuracy: 0.394
# Epoch 11/1000: Test accuracy: 0.394
# Epoch 12/1000: Test accuracy: 0.399
# Epoch 13/1000: Test accuracy: 0.396
# Epoch 14/1000: Test accuracy: 0.407
# Epoch 15/1000: Test accuracy: 0.404
# Epoch 16/1000: Test accuracy: 0.398
# Epoch 17/1000: Test accuracy: 0.41
# Epoch 18/1000: Test accuracy: 0.416
# Epoch 19/1000: Test accuracy: 0.422
# Epoch 20/1000: Test accuracy: 0.426
# Epoch 21/1000: Test accuracy: 0.425
# Epoch 22/1000: Test accuracy: 0.421
# Epoch 23/1000: Test accuracy: 0.427
# Epoch 24/1000: Test accuracy: 0.42
# Epoch 25/1000: Test accuracy: 0.419
# Epoch 26/1000: Test accuracy: 0.412
# Epoch 27/1000: Test accuracy: 0.411
# Epoch 28/1000: Test accuracy: 0.407
# Epoch 29/1000: Test accuracy: 0.402
# Epoch 30/1000: Test accuracy: 0.394
# Epoch 31/1000: Test accuracy: 0.4
# Epoch 32/1000: Test accuracy: 0.393
# Epoch 33/1000: Test accuracy: 0.393
# Epoch 34/1000: Test accuracy: 0.391
# Epoch 35/1000: Test accuracy: 0.389
# Epoch 36/1000: Test accuracy: 0.387
# Epoch 37/1000: Test accuracy: 0.385
# Epoch 38/1000: Test accuracy: 0.387
# Epoch 39/1000: Test accuracy: 0.39
# Epoch 40/1000: Test accuracy: 0.381
# Epoch 41/1000: Test accuracy: 0.381
# Epoch 42/1000: Test accuracy: 0.375
# Epoch 43/1000: Test accuracy: 0.376
# Epoch 44/1000: Test accuracy: 0.38
# Epoch 45/1000: Test accuracy: 0.382
# Epoch 46/1000: Test accuracy: 0.388
# Epoch 47/1000: Test accuracy: 0.383
# Epoch 48/1000: Test accuracy: 0.39
# Epoch 49/1000: Test accuracy: 0.391
# Epoch 50/1000: Test accuracy: 0.393
# Epoch 51/1000: Test accuracy: 0.392
# Epoch 52/1000: Test accuracy: 0.386
# Epoch 53/1000: Test accuracy: 0.392
# Epoch 54/1000: Test accuracy: 0.39
# Epoch 55/1000: Test accuracy: 0.398
# Epoch 56/1000: Test accuracy: 0.39
# Epoch 57/1000: Test accuracy: 0.397
# Epoch 58/1000: Test accuracy: 0.401
# Epoch 59/1000: Test accuracy: 0.403
# Epoch 60/1000: Test accuracy: 0.404
# Epoch 61/1000: Test accuracy: 0.404
# Epoch 62/1000: Test accuracy: 0.412
# Epoch 63/1000: Test accuracy: 0.4
# Epoch 64/1000: Test accuracy: 0.402
# Epoch 65/1000: Test accuracy: 0.405
# Epoch 66/1000: Test accuracy: 0.424
# Epoch 67/1000: Test accuracy: 0.412
# Epoch 68/1000: Test accuracy: 0.409
# Epoch 69/1000: Test accuracy: 0.419
# Epoch 70/1000: Test accuracy: 0.41
# Epoch 71/1000: Test accuracy: 0.414
# Epoch 72/1000: Test accuracy: 0.421
# Epoch 73/1000: Test accuracy: 0.417
# Epoch 74/1000: Test accuracy: 0.427
# Epoch 75/1000: Test accuracy: 0.432
# Epoch 76/1000: Test accuracy: 0.438
# Epoch 77/1000: Test accuracy: 0.445
# Epoch 78/1000: Test accuracy: 0.441
# Epoch 79/1000: Test accuracy: 0.434
# Epoch 80/1000: Test accuracy: 0.445
# Epoch 81/1000: Test accuracy: 0.448
# Epoch 82/1000: Test accuracy: 0.44
# Epoch 83/1000: Test accuracy: 0.456
# Epoch 84/1000: Test accuracy: 0.454
# Epoch 85/1000: Test accuracy: 0.448
# Epoch 86/1000: Test accuracy: 0.459
# Epoch 87/1000: Test accuracy: 0.444
# Epoch 88/1000: Test accuracy: 0.46
# Epoch 89/1000: Test accuracy: 0.459
# Epoch 90/1000: Test accuracy: 0.456
# Epoch 91/1000: Test accuracy: 0.47
# Epoch 92/1000: Test accuracy: 0.47
# Epoch 93/1000: Test accuracy: 0.464
# Epoch 94/1000: Test accuracy: 0.457
# Epoch 95/1000: Test accuracy: 0.481
# Epoch 96/1000: Test accuracy: 0.468
# Epoch 97/1000: Test accuracy: 0.476
# Epoch 98/1000: Test accuracy: 0.489
# Epoch 99/1000: Test accuracy: 0.506
# Epoch 100/1000: Test accuracy: 0.5
# Epoch 101/1000: Test accuracy: 0.511
# Epoch 102/1000: Test accuracy: 0.505
# Epoch 103/1000: Test accuracy: 0.491
# Epoch 104/1000: Test accuracy: 0.5
# Epoch 105/1000: Test accuracy: 0.508
# Epoch 106/1000: Test accuracy: 0.507
# Epoch 107/1000: Test accuracy: 0.509
# Epoch 108/1000: Test accuracy: 0.51
# Epoch 109/1000: Test accuracy: 0.507
# Epoch 110/1000: Test accuracy: 0.516
# Epoch 111/1000: Test accuracy: 0.515
# Epoch 112/1000: Test accuracy: 0.52
# Epoch 113/1000: Test accuracy: 0.512
# Epoch 114/1000: Test accuracy: 0.521
# Epoch 115/1000: Test accuracy: 0.518
# Epoch 116/1000: Test accuracy: 0.516
# Epoch 117/1000: Test accuracy: 0.522
# Epoch 118/1000: Test accuracy: 0.52
# Epoch 119/1000: Test accuracy: 0.519
# Epoch 120/1000: Test accuracy: 0.531
# Epoch 121/1000: Test accuracy: 0.527
# Epoch 122/1000: Test accuracy: 0.528
# Epoch 123/1000: Test accuracy: 0.525
# Epoch 124/1000: Test accuracy: 0.523
# Epoch 125/1000: Test accuracy: 0.515
# Epoch 126/1000: Test accuracy: 0.532
# Epoch 127/1000: Test accuracy: 0.527
# Epoch 128/1000: Test accuracy: 0.523
# Epoch 129/1000: Test accuracy: 0.527
# Epoch 130/1000: Test accuracy: 0.531
# Epoch 131/1000: Test accuracy: 0.526
# Epoch 132/1000: Test accuracy: 0.526
# Epoch 133/1000: Test accuracy: 0.531
# Epoch 134/1000: Test accuracy: 0.532
# Epoch 135/1000: Test accuracy: 0.524
# Epoch 136/1000: Test accuracy: 0.527
# Epoch 137/1000: Test accuracy: 0.526
# Epoch 138/1000: Test accuracy: 0.539
# Epoch 139/1000: Test accuracy: 0.53
# Epoch 140/1000: Test accuracy: 0.537
# Epoch 141/1000: Test accuracy: 0.532
# Epoch 142/1000: Test accuracy: 0.528
# Epoch 143/1000: Test accuracy: 0.528
# Epoch 144/1000: Test accuracy: 0.528
# Epoch 145/1000: Test accuracy: 0.527
# Epoch 146/1000: Test accuracy: 0.534
# Epoch 147/1000: Test accuracy: 0.53
# Epoch 148/1000: Test accuracy: 0.531
# Epoch 149/1000: Test accuracy: 0.533
# Epoch 150/1000: Test accuracy: 0.532
# Epoch 151/1000: Test accuracy: 0.53
# Epoch 152/1000: Test accuracy: 0.531
# Epoch 153/1000: Test accuracy: 0.527
# Epoch 154/1000: Test accuracy: 0.53
# Epoch 155/1000: Test accuracy: 0.532
# Epoch 156/1000: Test accuracy: 0.533
# Epoch 157/1000: Test accuracy: 0.531
# Epoch 158/1000: Test accuracy: 0.542
# Epoch 159/1000: Test accuracy: 0.523
# Epoch 160/1000: Test accuracy: 0.536
# Epoch 161/1000: Test accuracy: 0.532
# Epoch 162/1000: Test accuracy: 0.534
# Epoch 163/1000: Test accuracy: 0.529
# Epoch 164/1000: Test accuracy: 0.538
# Epoch 165/1000: Test accuracy: 0.535
# Epoch 166/1000: Test accuracy: 0.534
# Epoch 167/1000: Test accuracy: 0.532
# Epoch 168/1000: Test accuracy: 0.532
# Epoch 169/1000: Test accuracy: 0.53
# Epoch 170/1000: Test accuracy: 0.535
# Epoch 171/1000: Test accuracy: 0.528
# Epoch 172/1000: Test accuracy: 0.53
# Epoch 173/1000: Test accuracy: 0.528
# Epoch 174/1000: Test accuracy: 0.533
# Epoch 175/1000: Test accuracy: 0.525
# Epoch 176/1000: Test accuracy: 0.529
# Epoch 177/1000: Test accuracy: 0.528
# Epoch 178/1000: Test accuracy: 0.525
# Epoch 179/1000: Test accuracy: 0.528
# Epoch 180/1000: Test accuracy: 0.53
# Epoch 181/1000: Test accuracy: 0.529
# Epoch 182/1000: Test accuracy: 0.533
# Epoch 183/1000: Test accuracy: 0.53
# Epoch 184/1000: Test accuracy: 0.529
# Epoch 185/1000: Test accuracy: 0.527
# Epoch 186/1000: Test accuracy: 0.529
# Epoch 187/1000: Test accuracy: 0.53
# Epoch 188/1000: Test accuracy: 0.528
# Epoch 189/1000: Test accuracy: 0.526
# Epoch 190/1000: Test accuracy: 0.532
# Epoch 191/1000: Test accuracy: 0.528
# Epoch 192/1000: Test accuracy: 0.527
# Epoch 193/1000: Test accuracy: 0.534
# Epoch 194/1000: Test accuracy: 0.528
# Epoch 195/1000: Test accuracy: 0.531
# Epoch 196/1000: Test accuracy: 0.529
# Epoch 197/1000: Test accuracy: 0.53
# Epoch 198/1000: Test accuracy: 0.531
# Epoch 199/1000: Test accuracy: 0.532
# Epoch 200/1000: Test accuracy: 0.534
# Epoch 201/1000: Test accuracy: 0.531
# Epoch 202/1000: Test accuracy: 0.528
# Epoch 203/1000: Test accuracy: 0.53
# Epoch 204/1000: Test accuracy: 0.531
# Epoch 205/1000: Test accuracy: 0.534
# Epoch 206/1000: Test accuracy: 0.542
# Epoch 207/1000: Test accuracy: 0.534
# Epoch 208/1000: Test accuracy: 0.54
# Epoch 209/1000: Test accuracy: 0.537
# Epoch 210/1000: Test accuracy: 0.541
# Epoch 211/1000: Test accuracy: 0.536
# Epoch 212/1000: Test accuracy: 0.542
# Epoch 213/1000: Test accuracy: 0.536
# Epoch 214/1000: Test accuracy: 0.54
# Epoch 215/1000: Test accuracy: 0.542
# Epoch 216/1000: Test accuracy: 0.54
# Epoch 217/1000: Test accuracy: 0.544
# Epoch 218/1000: Test accuracy: 0.538
# Epoch 219/1000: Test accuracy: 0.546
# Epoch 220/1000: Test accuracy: 0.543
# Epoch 221/1000: Test accuracy: 0.542
# Epoch 222/1000: Test accuracy: 0.54
# Epoch 223/1000: Test accuracy: 0.542
# Epoch 224/1000: Test accuracy: 0.539
# Epoch 225/1000: Test accuracy: 0.542
# Epoch 226/1000: Test accuracy: 0.54
# Epoch 227/1000: Test accuracy: 0.542
# Epoch 228/1000: Test accuracy: 0.543
# Epoch 229/1000: Test accuracy: 0.542
# Epoch 230/1000: Test accuracy: 0.541
# Epoch 231/1000: Test accuracy: 0.539
# Epoch 232/1000: Test accuracy: 0.542
# Epoch 233/1000: Test accuracy: 0.537
# Epoch 234/1000: Test accuracy: 0.541
# Epoch 235/1000: Test accuracy: 0.546
# Epoch 236/1000: Test accuracy: 0.542
# Epoch 237/1000: Test accuracy: 0.549
# Epoch 238/1000: Test accuracy: 0.544
# Epoch 239/1000: Test accuracy: 0.542
# Epoch 240/1000: Test accuracy: 0.54
# Epoch 241/1000: Test accuracy: 0.545
# Epoch 242/1000: Test accuracy: 0.556
# Epoch 243/1000: Test accuracy: 0.542
# Epoch 244/1000: Test accuracy: 0.549
# Epoch 245/1000: Test accuracy: 0.546
# Epoch 246/1000: Test accuracy: 0.543
# Epoch 247/1000: Test accuracy: 0.553
# Epoch 248/1000: Test accuracy: 0.546
# Epoch 249/1000: Test accuracy: 0.551
# Epoch 250/1000: Test accuracy: 0.552
# Epoch 251/1000: Test accuracy: 0.556
# Epoch 252/1000: Test accuracy: 0.549
# Epoch 253/1000: Test accuracy: 0.558
# Epoch 254/1000: Test accuracy: 0.557
# Epoch 255/1000: Test accuracy: 0.555
# Epoch 256/1000: Test accuracy: 0.558
# Epoch 257/1000: Test accuracy: 0.562
# Epoch 258/1000: Test accuracy: 0.555
# Epoch 259/1000: Test accuracy: 0.553
# Epoch 260/1000: Test accuracy: 0.554
# Epoch 261/1000: Test accuracy: 0.552
# Epoch 262/1000: Test accuracy: 0.568
# Epoch 263/1000: Test accuracy: 0.562
# Epoch 264/1000: Test accuracy: 0.559
# Epoch 265/1000: Test accuracy: 0.563
# Epoch 266/1000: Test accuracy: 0.559
# Epoch 267/1000: Test accuracy: 0.562
# Epoch 268/1000: Test accuracy: 0.557
# Epoch 269/1000: Test accuracy: 0.558
# Epoch 270/1000: Test accuracy: 0.559
# Epoch 271/1000: Test accuracy: 0.56
# Epoch 272/1000: Test accuracy: 0.561
# Epoch 273/1000: Test accuracy: 0.565
# Epoch 274/1000: Test accuracy: 0.571
# Epoch 275/1000: Test accuracy: 0.568
# Epoch 276/1000: Test accuracy: 0.565
# Epoch 277/1000: Test accuracy: 0.566
# Epoch 278/1000: Test accuracy: 0.575
# Epoch 279/1000: Test accuracy: 0.568
# Epoch 280/1000: Test accuracy: 0.572
# Epoch 281/1000: Test accuracy: 0.569
# Epoch 282/1000: Test accuracy: 0.572
# Epoch 283/1000: Test accuracy: 0.571
# Epoch 284/1000: Test accuracy: 0.564
# Epoch 285/1000: Test accuracy: 0.572
# Epoch 286/1000: Test accuracy: 0.568
# Epoch 287/1000: Test accuracy: 0.576
# Epoch 288/1000: Test accuracy: 0.571
# Epoch 289/1000: Test accuracy: 0.572
# Epoch 290/1000: Test accuracy: 0.57
# Epoch 291/1000: Test accuracy: 0.575
# Epoch 292/1000: Test accuracy: 0.574
# Epoch 293/1000: Test accuracy: 0.575
# Epoch 294/1000: Test accuracy: 0.569
# Epoch 295/1000: Test accuracy: 0.573
# Epoch 296/1000: Test accuracy: 0.575
# Epoch 297/1000: Test accuracy: 0.579
# Epoch 298/1000: Test accuracy: 0.584
# Epoch 299/1000: Test accuracy: 0.574
# Epoch 300/1000: Test accuracy: 0.579
# Epoch 301/1000: Test accuracy: 0.575
# Epoch 302/1000: Test accuracy: 0.585
# Epoch 303/1000: Test accuracy: 0.572
# Epoch 304/1000: Test accuracy: 0.583
# Epoch 305/1000: Test accuracy: 0.57
# Epoch 306/1000: Test accuracy: 0.576
# Epoch 307/1000: Test accuracy: 0.584
# Epoch 308/1000: Test accuracy: 0.58
# Epoch 309/1000: Test accuracy: 0.588
# Epoch 310/1000: Test accuracy: 0.583
# Epoch 311/1000: Test accuracy: 0.579
# Epoch 312/1000: Test accuracy: 0.584
# Epoch 313/1000: Test accuracy: 0.581
# Epoch 314/1000: Test accuracy: 0.586
# Epoch 315/1000: Test accuracy: 0.59
# Epoch 316/1000: Test accuracy: 0.592
# Epoch 317/1000: Test accuracy: 0.586
# Epoch 318/1000: Test accuracy: 0.599
# Epoch 319/1000: Test accuracy: 0.589
# Epoch 320/1000: Test accuracy: 0.584
# Epoch 321/1000: Test accuracy: 0.589
# Epoch 322/1000: Test accuracy: 0.59
# Epoch 323/1000: Test accuracy: 0.594
# Epoch 324/1000: Test accuracy: 0.599
# Epoch 325/1000: Test accuracy: 0.592
# Epoch 326/1000: Test accuracy: 0.595
# Epoch 327/1000: Test accuracy: 0.593
# Epoch 328/1000: Test accuracy: 0.601
# Epoch 329/1000: Test accuracy: 0.598
# Epoch 330/1000: Test accuracy: 0.598
# Epoch 331/1000: Test accuracy: 0.592
# Epoch 332/1000: Test accuracy: 0.595
# Epoch 333/1000: Test accuracy: 0.596
# Epoch 334/1000: Test accuracy: 0.597
# Epoch 335/1000: Test accuracy: 0.604
# Epoch 336/1000: Test accuracy: 0.599
# Epoch 337/1000: Test accuracy: 0.595
# Epoch 338/1000: Test accuracy: 0.599
# Epoch 339/1000: Test accuracy: 0.594
# Epoch 340/1000: Test accuracy: 0.599
# Epoch 341/1000: Test accuracy: 0.601
# Epoch 342/1000: Test accuracy: 0.602
# Epoch 343/1000: Test accuracy: 0.605
# Epoch 344/1000: Test accuracy: 0.604
# Epoch 345/1000: Test accuracy: 0.603
# Epoch 346/1000: Test accuracy: 0.601
# Epoch 347/1000: Test accuracy: 0.599
# Epoch 348/1000: Test accuracy: 0.604
# Epoch 349/1000: Test accuracy: 0.606
# Epoch 350/1000: Test accuracy: 0.602
# Epoch 351/1000: Test accuracy: 0.61
# Epoch 352/1000: Test accuracy: 0.597
# Epoch 353/1000: Test accuracy: 0.605
# Epoch 354/1000: Test accuracy: 0.598
# Epoch 355/1000: Test accuracy: 0.611
# Epoch 356/1000: Test accuracy: 0.605
# Epoch 357/1000: Test accuracy: 0.609
# Epoch 358/1000: Test accuracy: 0.605
# Epoch 359/1000: Test accuracy: 0.61
# Epoch 360/1000: Test accuracy: 0.607
# Epoch 361/1000: Test accuracy: 0.606
# Epoch 362/1000: Test accuracy: 0.606
# Epoch 363/1000: Test accuracy: 0.61
# Epoch 364/1000: Test accuracy: 0.607
# Epoch 365/1000: Test accuracy: 0.603
# Epoch 366/1000: Test accuracy: 0.607
# Epoch 367/1000: Test accuracy: 0.603
# Epoch 368/1000: Test accuracy: 0.606
# Epoch 369/1000: Test accuracy: 0.608
# Epoch 370/1000: Test accuracy: 0.606
# Epoch 371/1000: Test accuracy: 0.61
# Epoch 372/1000: Test accuracy: 0.609
# Epoch 373/1000: Test accuracy: 0.61
# Epoch 374/1000: Test accuracy: 0.61
# Epoch 375/1000: Test accuracy: 0.608
# Epoch 376/1000: Test accuracy: 0.611
# Epoch 377/1000: Test accuracy: 0.614
# Epoch 378/1000: Test accuracy: 0.606
# Epoch 379/1000: Test accuracy: 0.61
# Epoch 380/1000: Test accuracy: 0.606
# Epoch 381/1000: Test accuracy: 0.613
# Epoch 382/1000: Test accuracy: 0.608
# Epoch 383/1000: Test accuracy: 0.607
# Epoch 384/1000: Test accuracy: 0.606
# Epoch 385/1000: Test accuracy: 0.613
# Epoch 386/1000: Test accuracy: 0.608
# Epoch 387/1000: Test accuracy: 0.61
# Epoch 388/1000: Test accuracy: 0.61
# Epoch 389/1000: Test accuracy: 0.611
# Epoch 390/1000: Test accuracy: 0.603
# Epoch 391/1000: Test accuracy: 0.607
# Epoch 392/1000: Test accuracy: 0.608
# Epoch 393/1000: Test accuracy: 0.608
# Epoch 394/1000: Test accuracy: 0.61
# Epoch 395/1000: Test accuracy: 0.612
# Epoch 396/1000: Test accuracy: 0.607
# Epoch 397/1000: Test accuracy: 0.61
# Epoch 398/1000: Test accuracy: 0.606
# Epoch 399/1000: Test accuracy: 0.609
# Epoch 400/1000: Test accuracy: 0.61
# Epoch 401/1000: Test accuracy: 0.61
# Epoch 402/1000: Test accuracy: 0.615
# Epoch 403/1000: Test accuracy: 0.611
# Epoch 404/1000: Test accuracy: 0.614
# Epoch 405/1000: Test accuracy: 0.602
# Epoch 406/1000: Test accuracy: 0.613
# Epoch 407/1000: Test accuracy: 0.617
# Epoch 408/1000: Test accuracy: 0.62
# Epoch 409/1000: Test accuracy: 0.613
# Epoch 410/1000: Test accuracy: 0.61
# Epoch 411/1000: Test accuracy: 0.606
# Epoch 412/1000: Test accuracy: 0.615
# Epoch 413/1000: Test accuracy: 0.607
# Epoch 414/1000: Test accuracy: 0.619
# Epoch 415/1000: Test accuracy: 0.615
# Epoch 416/1000: Test accuracy: 0.617
# Epoch 417/1000: Test accuracy: 0.607
# Epoch 418/1000: Test accuracy: 0.618
# Epoch 419/1000: Test accuracy: 0.606
# Epoch 420/1000: Test accuracy: 0.612
# Epoch 421/1000: Test accuracy: 0.604
# Epoch 422/1000: Test accuracy: 0.618
# Epoch 423/1000: Test accuracy: 0.611
# Epoch 424/1000: Test accuracy: 0.619
# Epoch 425/1000: Test accuracy: 0.615
# Epoch 426/1000: Test accuracy: 0.611
# Epoch 427/1000: Test accuracy: 0.609
# Epoch 428/1000: Test accuracy: 0.614
# Epoch 429/1000: Test accuracy: 0.617
# Epoch 430/1000: Test accuracy: 0.609
# Epoch 431/1000: Test accuracy: 0.612
# Epoch 432/1000: Test accuracy: 0.607
# Epoch 433/1000: Test accuracy: 0.608
# Epoch 434/1000: Test accuracy: 0.608
# Epoch 435/1000: Test accuracy: 0.614
# Epoch 436/1000: Test accuracy: 0.616
# Epoch 437/1000: Test accuracy: 0.613
# Epoch 438/1000: Test accuracy: 0.61
# Epoch 439/1000: Test accuracy: 0.615
# Epoch 440/1000: Test accuracy: 0.619
# Epoch 441/1000: Test accuracy: 0.611
# Epoch 442/1000: Test accuracy: 0.612
# Epoch 443/1000: Test accuracy: 0.6
# Epoch 444/1000: Test accuracy: 0.62
# Epoch 445/1000: Test accuracy: 0.617
# Epoch 446/1000: Test accuracy: 0.612
# Epoch 447/1000: Test accuracy: 0.613
# Epoch 448/1000: Test accuracy: 0.609
# Epoch 449/1000: Test accuracy: 0.62
# Epoch 450/1000: Test accuracy: 0.616
# Epoch 451/1000: Test accuracy: 0.614
# Epoch 452/1000: Test accuracy: 0.619
# Epoch 453/1000: Test accuracy: 0.614
# Epoch 454/1000: Test accuracy: 0.617
# Epoch 455/1000: Test accuracy: 0.622
# Epoch 456/1000: Test accuracy: 0.615
# Epoch 457/1000: Test accuracy: 0.618
# Epoch 458/1000: Test accuracy: 0.615
# Epoch 459/1000: Test accuracy: 0.618
# Epoch 460/1000: Test accuracy: 0.615
# Epoch 461/1000: Test accuracy: 0.617
# Epoch 462/1000: Test accuracy: 0.615
# Epoch 463/1000: Test accuracy: 0.62
# Epoch 464/1000: Test accuracy: 0.616
# Epoch 465/1000: Test accuracy: 0.621
# Epoch 466/1000: Test accuracy: 0.622
# Epoch 467/1000: Test accuracy: 0.624
# Epoch 468/1000: Test accuracy: 0.626
# Epoch 469/1000: Test accuracy: 0.626
# Epoch 470/1000: Test accuracy: 0.623
# Epoch 471/1000: Test accuracy: 0.633
# Epoch 472/1000: Test accuracy: 0.627
# Epoch 473/1000: Test accuracy: 0.628
# Epoch 474/1000: Test accuracy: 0.621
# Epoch 475/1000: Test accuracy: 0.631
# Epoch 476/1000: Test accuracy: 0.63
# Epoch 477/1000: Test accuracy: 0.609
# Epoch 478/1000: Test accuracy: 0.627
# Epoch 479/1000: Test accuracy: 0.633
# Epoch 480/1000: Test accuracy: 0.628
# Epoch 481/1000: Test accuracy: 0.639
# Epoch 482/1000: Test accuracy: 0.631
# Epoch 483/1000: Test accuracy: 0.634
# Epoch 484/1000: Test accuracy: 0.632
# Epoch 485/1000: Test accuracy: 0.621
# Epoch 486/1000: Test accuracy: 0.632
# Epoch 487/1000: Test accuracy: 0.629
# Epoch 488/1000: Test accuracy: 0.629
# Epoch 489/1000: Test accuracy: 0.631
# Epoch 490/1000: Test accuracy: 0.636
# Epoch 491/1000: Test accuracy: 0.631
# Epoch 492/1000: Test accuracy: 0.631
# Epoch 493/1000: Test accuracy: 0.633
# Epoch 494/1000: Test accuracy: 0.634
# Epoch 495/1000: Test accuracy: 0.639
# Epoch 496/1000: Test accuracy: 0.636
# Epoch 497/1000: Test accuracy: 0.624
# Epoch 498/1000: Test accuracy: 0.638
# Epoch 499/1000: Test accuracy: 0.638
# Epoch 500/1000: Test accuracy: 0.638
# Epoch 501/1000: Test accuracy: 0.632
# Epoch 502/1000: Test accuracy: 0.641
# Epoch 503/1000: Test accuracy: 0.636
# Epoch 504/1000: Test accuracy: 0.638
# Epoch 505/1000: Test accuracy: 0.635
# Epoch 506/1000: Test accuracy: 0.633
# Epoch 507/1000: Test accuracy: 0.633
# Epoch 508/1000: Test accuracy: 0.634
# Epoch 509/1000: Test accuracy: 0.639
# Epoch 510/1000: Test accuracy: 0.641
# Epoch 511/1000: Test accuracy: 0.637
# Epoch 512/1000: Test accuracy: 0.63
# Epoch 513/1000: Test accuracy: 0.64
# Epoch 514/1000: Test accuracy: 0.643
# Epoch 515/1000: Test accuracy: 0.629
# Epoch 516/1000: Test accuracy: 0.641
# Epoch 517/1000: Test accuracy: 0.632
# Epoch 518/1000: Test accuracy: 0.631
# Epoch 519/1000: Test accuracy: 0.636
# Epoch 520/1000: Test accuracy: 0.637
# Epoch 521/1000: Test accuracy: 0.634
# Epoch 522/1000: Test accuracy: 0.639
# Epoch 523/1000: Test accuracy: 0.637
# Epoch 524/1000: Test accuracy: 0.645
# Epoch 525/1000: Test accuracy: 0.638
# Epoch 526/1000: Test accuracy: 0.638
# Epoch 527/1000: Test accuracy: 0.642
# Epoch 528/1000: Test accuracy: 0.632
# Epoch 529/1000: Test accuracy: 0.643
# Epoch 530/1000: Test accuracy: 0.64
# Epoch 531/1000: Test accuracy: 0.642
# Epoch 532/1000: Test accuracy: 0.634
# Epoch 533/1000: Test accuracy: 0.643
# Epoch 534/1000: Test accuracy: 0.643
# Epoch 535/1000: Test accuracy: 0.642
# Epoch 536/1000: Test accuracy: 0.637
# Epoch 537/1000: Test accuracy: 0.642
# Epoch 538/1000: Test accuracy: 0.641
# Epoch 539/1000: Test accuracy: 0.641
# Epoch 540/1000: Test accuracy: 0.64
# Epoch 541/1000: Test accuracy: 0.634
# Epoch 542/1000: Test accuracy: 0.638
# Epoch 543/1000: Test accuracy: 0.639
# Epoch 544/1000: Test accuracy: 0.638
# Epoch 545/1000: Test accuracy: 0.641
# Epoch 546/1000: Test accuracy: 0.638
# Epoch 547/1000: Test accuracy: 0.635
# Epoch 548/1000: Test accuracy: 0.634
# Epoch 549/1000: Test accuracy: 0.645
# Epoch 550/1000: Test accuracy: 0.633
# Epoch 551/1000: Test accuracy: 0.642
# Epoch 552/1000: Test accuracy: 0.645
# Epoch 553/1000: Test accuracy: 0.636
# Epoch 554/1000: Test accuracy: 0.642
# Epoch 555/1000: Test accuracy: 0.645
# Epoch 556/1000: Test accuracy: 0.638
# Epoch 557/1000: Test accuracy: 0.64
# Epoch 558/1000: Test accuracy: 0.641
# Epoch 559/1000: Test accuracy: 0.635
# Epoch 560/1000: Test accuracy: 0.649
# Epoch 561/1000: Test accuracy: 0.638
# Epoch 562/1000: Test accuracy: 0.64
# Epoch 563/1000: Test accuracy: 0.646
# Epoch 564/1000: Test accuracy: 0.647
# Epoch 565/1000: Test accuracy: 0.643
# Epoch 566/1000: Test accuracy: 0.64
# Epoch 567/1000: Test accuracy: 0.648
# Epoch 568/1000: Test accuracy: 0.646
# Epoch 569/1000: Test accuracy: 0.645
# Epoch 570/1000: Test accuracy: 0.645
# Epoch 571/1000: Test accuracy: 0.645
# Epoch 572/1000: Test accuracy: 0.642
# Epoch 573/1000: Test accuracy: 0.652
# Epoch 574/1000: Test accuracy: 0.639
# Epoch 575/1000: Test accuracy: 0.653
# Epoch 576/1000: Test accuracy: 0.647
# Epoch 577/1000: Test accuracy: 0.65
# Epoch 578/1000: Test accuracy: 0.647
# Epoch 579/1000: Test accuracy: 0.655
# Epoch 580/1000: Test accuracy: 0.648
# Epoch 581/1000: Test accuracy: 0.643
# Epoch 582/1000: Test accuracy: 0.651
# Epoch 583/1000: Test accuracy: 0.651
# Epoch 584/1000: Test accuracy: 0.644
# Epoch 585/1000: Test accuracy: 0.655
# Epoch 586/1000: Test accuracy: 0.636
# Epoch 587/1000: Test accuracy: 0.644
# Epoch 588/1000: Test accuracy: 0.655
# Epoch 589/1000: Test accuracy: 0.65
# Epoch 590/1000: Test accuracy: 0.652
# Epoch 591/1000: Test accuracy: 0.657
# Epoch 592/1000: Test accuracy: 0.645
# Epoch 593/1000: Test accuracy: 0.658
# Epoch 594/1000: Test accuracy: 0.655
# Epoch 595/1000: Test accuracy: 0.662
# Epoch 596/1000: Test accuracy: 0.658
# Epoch 597/1000: Test accuracy: 0.647
# Epoch 598/1000: Test accuracy: 0.658
# Epoch 599/1000: Test accuracy: 0.656
# Epoch 600/1000: Test accuracy: 0.659
# Epoch 601/1000: Test accuracy: 0.649
# Epoch 602/1000: Test accuracy: 0.661
# Epoch 603/1000: Test accuracy: 0.652
# Epoch 604/1000: Test accuracy: 0.648
# Epoch 605/1000: Test accuracy: 0.649
# Epoch 606/1000: Test accuracy: 0.665
# Epoch 607/1000: Test accuracy: 0.659
# Epoch 608/1000: Test accuracy: 0.654
# Epoch 609/1000: Test accuracy: 0.656
# Epoch 610/1000: Test accuracy: 0.659
# Epoch 611/1000: Test accuracy: 0.653
# Epoch 612/1000: Test accuracy: 0.665
# Epoch 613/1000: Test accuracy: 0.658
# Epoch 614/1000: Test accuracy: 0.658
# Epoch 615/1000: Test accuracy: 0.654
# Epoch 616/1000: Test accuracy: 0.658
# Epoch 617/1000: Test accuracy: 0.649
# Epoch 618/1000: Test accuracy: 0.666
# Epoch 619/1000: Test accuracy: 0.657
# Epoch 620/1000: Test accuracy: 0.658
# Epoch 621/1000: Test accuracy: 0.667
# Epoch 622/1000: Test accuracy: 0.654
# Epoch 623/1000: Test accuracy: 0.668
# Epoch 624/1000: Test accuracy: 0.666
# Epoch 625/1000: Test accuracy: 0.66
# Epoch 626/1000: Test accuracy: 0.657
# Epoch 627/1000: Test accuracy: 0.661
# Epoch 628/1000: Test accuracy: 0.658
# Epoch 629/1000: Test accuracy: 0.666
# Epoch 630/1000: Test accuracy: 0.668
# Epoch 631/1000: Test accuracy: 0.654
# Epoch 632/1000: Test accuracy: 0.655
# Epoch 633/1000: Test accuracy: 0.667
# Epoch 634/1000: Test accuracy: 0.663
# Epoch 635/1000: Test accuracy: 0.658
# Epoch 636/1000: Test accuracy: 0.669
# Epoch 637/1000: Test accuracy: 0.668
# Epoch 638/1000: Test accuracy: 0.665
# Epoch 639/1000: Test accuracy: 0.667
# Epoch 640/1000: Test accuracy: 0.666
# Epoch 641/1000: Test accuracy: 0.661
# Epoch 642/1000: Test accuracy: 0.668
# Epoch 643/1000: Test accuracy: 0.662
# Epoch 644/1000: Test accuracy: 0.664
# Epoch 645/1000: Test accuracy: 0.665
# Epoch 646/1000: Test accuracy: 0.668
# Epoch 647/1000: Test accuracy: 0.667
# Epoch 648/1000: Test accuracy: 0.663
# Epoch 649/1000: Test accuracy: 0.662
# Epoch 650/1000: Test accuracy: 0.663
# Epoch 651/1000: Test accuracy: 0.663
# Epoch 652/1000: Test accuracy: 0.667
# Epoch 653/1000: Test accuracy: 0.665
# Epoch 654/1000: Test accuracy: 0.666
# Epoch 655/1000: Test accuracy: 0.658
# Epoch 656/1000: Test accuracy: 0.664
# Epoch 657/1000: Test accuracy: 0.658
# Epoch 658/1000: Test accuracy: 0.66
# Epoch 659/1000: Test accuracy: 0.662
# Epoch 660/1000: Test accuracy: 0.672
# Epoch 661/1000: Test accuracy: 0.667
# Epoch 662/1000: Test accuracy: 0.672
# Epoch 663/1000: Test accuracy: 0.675
# Epoch 664/1000: Test accuracy: 0.667
# Epoch 665/1000: Test accuracy: 0.674
# Epoch 666/1000: Test accuracy: 0.673
# Epoch 667/1000: Test accuracy: 0.66
# Epoch 668/1000: Test accuracy: 0.658
# Epoch 669/1000: Test accuracy: 0.664
# Epoch 670/1000: Test accuracy: 0.661
# Epoch 671/1000: Test accuracy: 0.664
# Epoch 672/1000: Test accuracy: 0.666
# Epoch 673/1000: Test accuracy: 0.665
# Epoch 674/1000: Test accuracy: 0.667
# Epoch 675/1000: Test accuracy: 0.665
# Epoch 676/1000: Test accuracy: 0.664
# Epoch 677/1000: Test accuracy: 0.672
# Epoch 678/1000: Test accuracy: 0.667
# Epoch 679/1000: Test accuracy: 0.668
# Epoch 680/1000: Test accuracy: 0.666
# Epoch 681/1000: Test accuracy: 0.663
# Epoch 682/1000: Test accuracy: 0.666
# Epoch 683/1000: Test accuracy: 0.665
# Epoch 684/1000: Test accuracy: 0.668
# Epoch 685/1000: Test accuracy: 0.675
# Epoch 686/1000: Test accuracy: 0.674
# Epoch 687/1000: Test accuracy: 0.673
# Epoch 688/1000: Test accuracy: 0.669
# Epoch 689/1000: Test accuracy: 0.663
# Epoch 690/1000: Test accuracy: 0.676
# Epoch 691/1000: Test accuracy: 0.672
# Epoch 692/1000: Test accuracy: 0.676
# Epoch 693/1000: Test accuracy: 0.669
# Epoch 694/1000: Test accuracy: 0.677
# Epoch 695/1000: Test accuracy: 0.667
# Epoch 696/1000: Test accuracy: 0.66
# Epoch 697/1000: Test accuracy: 0.667
# Epoch 698/1000: Test accuracy: 0.665
# Epoch 699/1000: Test accuracy: 0.667
# Epoch 700/1000: Test accuracy: 0.67
# Epoch 701/1000: Test accuracy: 0.672
# Epoch 702/1000: Test accuracy: 0.665
# Epoch 703/1000: Test accuracy: 0.669
# Epoch 704/1000: Test accuracy: 0.67
# Epoch 705/1000: Test accuracy: 0.664
# Epoch 706/1000: Test accuracy: 0.67
# Epoch 707/1000: Test accuracy: 0.668
# Epoch 708/1000: Test accuracy: 0.672
# Epoch 709/1000: Test accuracy: 0.673
# Epoch 710/1000: Test accuracy: 0.666
# Epoch 711/1000: Test accuracy: 0.672
# Epoch 712/1000: Test accuracy: 0.666
# Epoch 713/1000: Test accuracy: 0.675
# Epoch 714/1000: Test accuracy: 0.668
# Epoch 715/1000: Test accuracy: 0.661
# Epoch 716/1000: Test accuracy: 0.663
# Epoch 717/1000: Test accuracy: 0.664
# Epoch 718/1000: Test accuracy: 0.668
# Epoch 719/1000: Test accuracy: 0.672
# Epoch 720/1000: Test accuracy: 0.667
# Epoch 721/1000: Test accuracy: 0.67
# Epoch 722/1000: Test accuracy: 0.676
# Epoch 723/1000: Test accuracy: 0.677
# Epoch 724/1000: Test accuracy: 0.66
# Epoch 725/1000: Test accuracy: 0.662
# Epoch 726/1000: Test accuracy: 0.667
# Epoch 727/1000: Test accuracy: 0.672
# Epoch 728/1000: Test accuracy: 0.668
# Epoch 729/1000: Test accuracy: 0.676
# Epoch 730/1000: Test accuracy: 0.665
# Epoch 731/1000: Test accuracy: 0.672
# Epoch 732/1000: Test accuracy: 0.668
# Epoch 733/1000: Test accuracy: 0.674
# Epoch 734/1000: Test accuracy: 0.679
# Epoch 735/1000: Test accuracy: 0.663
# Epoch 736/1000: Test accuracy: 0.676
# Epoch 737/1000: Test accuracy: 0.674
# Epoch 738/1000: Test accuracy: 0.67
# Epoch 739/1000: Test accuracy: 0.673
# Epoch 740/1000: Test accuracy: 0.672
# Epoch 741/1000: Test accuracy: 0.662
# Epoch 742/1000: Test accuracy: 0.671
# Epoch 743/1000: Test accuracy: 0.679
# Epoch 744/1000: Test accuracy: 0.677
# Epoch 745/1000: Test accuracy: 0.675
# Epoch 746/1000: Test accuracy: 0.671
# Epoch 747/1000: Test accuracy: 0.67
# Epoch 748/1000: Test accuracy: 0.662
# Epoch 749/1000: Test accuracy: 0.676
# Epoch 750/1000: Test accuracy: 0.671
# Epoch 751/1000: Test accuracy: 0.672
# Epoch 752/1000: Test accuracy: 0.673
# Epoch 753/1000: Test accuracy: 0.676
# Epoch 754/1000: Test accuracy: 0.668
# Epoch 755/1000: Test accuracy: 0.681
# Epoch 756/1000: Test accuracy: 0.67
# Epoch 757/1000: Test accuracy: 0.672
# Epoch 758/1000: Test accuracy: 0.673
# Epoch 759/1000: Test accuracy: 0.679
# Epoch 760/1000: Test accuracy: 0.678
# Epoch 761/1000: Test accuracy: 0.673
# Epoch 762/1000: Test accuracy: 0.672
# Epoch 763/1000: Test accuracy: 0.663
# Epoch 764/1000: Test accuracy: 0.676
# Epoch 765/1000: Test accuracy: 0.675
# Epoch 766/1000: Test accuracy: 0.672
# Epoch 767/1000: Test accuracy: 0.674
# Epoch 768/1000: Test accuracy: 0.671
# Epoch 769/1000: Test accuracy: 0.667
# Epoch 770/1000: Test accuracy: 0.675
# Epoch 771/1000: Test accuracy: 0.67
# Epoch 772/1000: Test accuracy: 0.678
# Epoch 773/1000: Test accuracy: 0.664
# Epoch 774/1000: Test accuracy: 0.679
# Epoch 775/1000: Test accuracy: 0.666
# Epoch 776/1000: Test accuracy: 0.676
# Epoch 777/1000: Test accuracy: 0.67
# Epoch 778/1000: Test accuracy: 0.678
# Epoch 779/1000: Test accuracy: 0.675
# Epoch 780/1000: Test accuracy: 0.677
# Epoch 781/1000: Test accuracy: 0.678
# Epoch 782/1000: Test accuracy: 0.675
# Epoch 783/1000: Test accuracy: 0.679
# Epoch 784/1000: Test accuracy: 0.674
# Epoch 785/1000: Test accuracy: 0.676
# Epoch 786/1000: Test accuracy: 0.68
# Epoch 787/1000: Test accuracy: 0.677
# Epoch 788/1000: Test accuracy: 0.678
# Epoch 789/1000: Test accuracy: 0.675
# Epoch 790/1000: Test accuracy: 0.68
# Epoch 791/1000: Test accuracy: 0.678
# Epoch 792/1000: Test accuracy: 0.674
# Epoch 793/1000: Test accuracy: 0.668
# Epoch 794/1000: Test accuracy: 0.682
# Epoch 795/1000: Test accuracy: 0.665
# Epoch 796/1000: Test accuracy: 0.674
# Epoch 797/1000: Test accuracy: 0.677
# Epoch 798/1000: Test accuracy: 0.674
# Epoch 799/1000: Test accuracy: 0.682
# Epoch 800/1000: Test accuracy: 0.674
# Epoch 801/1000: Test accuracy: 0.676
# Epoch 802/1000: Test accuracy: 0.671
# Epoch 803/1000: Test accuracy: 0.676
# Epoch 804/1000: Test accuracy: 0.668
# Epoch 805/1000: Test accuracy: 0.684
# Epoch 806/1000: Test accuracy: 0.666
# Epoch 807/1000: Test accuracy: 0.673
# Epoch 808/1000: Test accuracy: 0.684
# Epoch 809/1000: Test accuracy: 0.668
# Epoch 810/1000: Test accuracy: 0.679
# Epoch 811/1000: Test accuracy: 0.665
# Epoch 812/1000: Test accuracy: 0.686
# Epoch 813/1000: Test accuracy: 0.681
# Epoch 814/1000: Test accuracy: 0.679
# Epoch 815/1000: Test accuracy: 0.678
# Epoch 816/1000: Test accuracy: 0.68
# Epoch 817/1000: Test accuracy: 0.684
# Epoch 818/1000: Test accuracy: 0.682
# Epoch 819/1000: Test accuracy: 0.675
# Epoch 820/1000: Test accuracy: 0.676
# Epoch 821/1000: Test accuracy: 0.674
# Epoch 822/1000: Test accuracy: 0.684
# Epoch 823/1000: Test accuracy: 0.68
# Epoch 824/1000: Test accuracy: 0.675
# Epoch 825/1000: Test accuracy: 0.682
# Epoch 826/1000: Test accuracy: 0.669
# Epoch 827/1000: Test accuracy: 0.682
# Epoch 828/1000: Test accuracy: 0.676
# Epoch 829/1000: Test accuracy: 0.671
# Epoch 830/1000: Test accuracy: 0.675
# Epoch 831/1000: Test accuracy: 0.677
# Epoch 832/1000: Test accuracy: 0.682
# Epoch 833/1000: Test accuracy: 0.678
# Epoch 834/1000: Test accuracy: 0.675
# Epoch 835/1000: Test accuracy: 0.671
# Epoch 836/1000: Test accuracy: 0.668
# Epoch 837/1000: Test accuracy: 0.68
# Epoch 838/1000: Test accuracy: 0.669
# Epoch 839/1000: Test accuracy: 0.676
# Epoch 840/1000: Test accuracy: 0.668
# Epoch 841/1000: Test accuracy: 0.671
# Epoch 842/1000: Test accuracy: 0.683
# Epoch 843/1000: Test accuracy: 0.682
# Epoch 844/1000: Test accuracy: 0.679
# Epoch 845/1000: Test accuracy: 0.683
# Epoch 846/1000: Test accuracy: 0.678
# Epoch 847/1000: Test accuracy: 0.682
# Epoch 848/1000: Test accuracy: 0.686
# Epoch 849/1000: Test accuracy: 0.684
# Epoch 850/1000: Test accuracy: 0.677
# Epoch 851/1000: Test accuracy: 0.682
# Epoch 852/1000: Test accuracy: 0.669
# Epoch 853/1000: Test accuracy: 0.676
# Epoch 854/1000: Test accuracy: 0.684
# Epoch 855/1000: Test accuracy: 0.676
# Epoch 856/1000: Test accuracy: 0.677
# Epoch 857/1000: Test accuracy: 0.671
# Epoch 858/1000: Test accuracy: 0.687
# Epoch 859/1000: Test accuracy: 0.687
# Epoch 860/1000: Test accuracy: 0.674
# Epoch 861/1000: Test accuracy: 0.684
# Epoch 862/1000: Test accuracy: 0.68
# Epoch 863/1000: Test accuracy: 0.687
# Epoch 864/1000: Test accuracy: 0.677
# Epoch 865/1000: Test accuracy: 0.672
# Epoch 866/1000: Test accuracy: 0.68
# Epoch 867/1000: Test accuracy: 0.674
# Epoch 868/1000: Test accuracy: 0.673
# Epoch 869/1000: Test accuracy: 0.675
# Epoch 870/1000: Test accuracy: 0.676
# Epoch 871/1000: Test accuracy: 0.684
# Epoch 872/1000: Test accuracy: 0.682
# Epoch 873/1000: Test accuracy: 0.677
# Epoch 874/1000: Test accuracy: 0.688
# Epoch 875/1000: Test accuracy: 0.679
# Epoch 876/1000: Test accuracy: 0.677
# Epoch 877/1000: Test accuracy: 0.683
# Epoch 878/1000: Test accuracy: 0.685
# Epoch 879/1000: Test accuracy: 0.675
# Epoch 880/1000: Test accuracy: 0.675
# Epoch 881/1000: Test accuracy: 0.676
# Epoch 882/1000: Test accuracy: 0.68
# Epoch 883/1000: Test accuracy: 0.678
# Epoch 884/1000: Test accuracy: 0.678
# Epoch 885/1000: Test accuracy: 0.675
# Epoch 886/1000: Test accuracy: 0.678
# Epoch 887/1000: Test accuracy: 0.681
# Epoch 888/1000: Test accuracy: 0.677
# Epoch 889/1000: Test accuracy: 0.673
# Epoch 890/1000: Test accuracy: 0.674
# Epoch 891/1000: Test accuracy: 0.683
# Epoch 892/1000: Test accuracy: 0.673
# Epoch 893/1000: Test accuracy: 0.684
# Epoch 894/1000: Test accuracy: 0.686
# Epoch 895/1000: Test accuracy: 0.68
# Epoch 896/1000: Test accuracy: 0.69
# Epoch 897/1000: Test accuracy: 0.678
# Epoch 898/1000: Test accuracy: 0.675
# Epoch 899/1000: Test accuracy: 0.677
# Epoch 900/1000: Test accuracy: 0.677
# Epoch 901/1000: Test accuracy: 0.678
# Epoch 902/1000: Test accuracy: 0.687
# Epoch 903/1000: Test accuracy: 0.68
# Epoch 904/1000: Test accuracy: 0.686
# Epoch 905/1000: Test accuracy: 0.677
# Epoch 906/1000: Test accuracy: 0.677
# Epoch 907/1000: Test accuracy: 0.681
# Epoch 908/1000: Test accuracy: 0.687
# Epoch 909/1000: Test accuracy: 0.69
# Epoch 910/1000: Test accuracy: 0.687
# Epoch 911/1000: Test accuracy: 0.678
# Epoch 912/1000: Test accuracy: 0.682
# Epoch 913/1000: Test accuracy: 0.683
# Epoch 914/1000: Test accuracy: 0.685
# Epoch 915/1000: Test accuracy: 0.682
# Epoch 916/1000: Test accuracy: 0.676
# Epoch 917/1000: Test accuracy: 0.688
# Epoch 918/1000: Test accuracy: 0.681
# Epoch 919/1000: Test accuracy: 0.682
# Epoch 920/1000: Test accuracy: 0.684
# Epoch 921/1000: Test accuracy: 0.683
# Epoch 922/1000: Test accuracy: 0.684
# Epoch 923/1000: Test accuracy: 0.689
# Epoch 924/1000: Test accuracy: 0.683
# Epoch 925/1000: Test accuracy: 0.687
# Epoch 926/1000: Test accuracy: 0.682
# Epoch 927/1000: Test accuracy: 0.682
# Epoch 928/1000: Test accuracy: 0.688
# Epoch 929/1000: Test accuracy: 0.68
# Epoch 930/1000: Test accuracy: 0.682
# Epoch 931/1000: Test accuracy: 0.68
# Epoch 932/1000: Test accuracy: 0.687
# Epoch 933/1000: Test accuracy: 0.689
# Epoch 934/1000: Test accuracy: 0.683
# Epoch 935/1000: Test accuracy: 0.683
# Epoch 936/1000: Test accuracy: 0.689
# Epoch 937/1000: Test accuracy: 0.681
# Epoch 938/1000: Test accuracy: 0.694
# Epoch 939/1000: Test accuracy: 0.682
# Epoch 940/1000: Test accuracy: 0.691
# Epoch 941/1000: Test accuracy: 0.684
# Epoch 942/1000: Test accuracy: 0.688
# Epoch 943/1000: Test accuracy: 0.678
# Epoch 944/1000: Test accuracy: 0.694
# Epoch 945/1000: Test accuracy: 0.68
# Epoch 946/1000: Test accuracy: 0.681
# Epoch 947/1000: Test accuracy: 0.677
# Epoch 948/1000: Test accuracy: 0.679
# Epoch 949/1000: Test accuracy: 0.69
# Epoch 950/1000: Test accuracy: 0.688
# Epoch 951/1000: Test accuracy: 0.693
# Epoch 952/1000: Test accuracy: 0.683
# Epoch 953/1000: Test accuracy: 0.682
# Epoch 954/1000: Test accuracy: 0.686
# Epoch 955/1000: Test accuracy: 0.687
# Epoch 956/1000: Test accuracy: 0.691
# Epoch 957/1000: Test accuracy: 0.69
# Epoch 958/1000: Test accuracy: 0.686
# Epoch 959/1000: Test accuracy: 0.691
# Epoch 960/1000: Test accuracy: 0.692
# Epoch 961/1000: Test accuracy: 0.698
# Epoch 962/1000: Test accuracy: 0.683
# Epoch 963/1000: Test accuracy: 0.685
# Epoch 964/1000: Test accuracy: 0.695
# Epoch 965/1000: Test accuracy: 0.694
# Epoch 966/1000: Test accuracy: 0.693
# Epoch 967/1000: Test accuracy: 0.685
# Epoch 968/1000: Test accuracy: 0.692
# Epoch 969/1000: Test accuracy: 0.688
# Epoch 970/1000: Test accuracy: 0.691
# Epoch 971/1000: Test accuracy: 0.695
# Epoch 972/1000: Test accuracy: 0.69
# Epoch 973/1000: Test accuracy: 0.69
# Epoch 974/1000: Test accuracy: 0.686
# Epoch 975/1000: Test accuracy: 0.696
# Epoch 976/1000: Test accuracy: 0.691
# Epoch 977/1000: Test accuracy: 0.69
# Epoch 978/1000: Test accuracy: 0.692
# Epoch 979/1000: Test accuracy: 0.688
# Epoch 980/1000: Test accuracy: 0.687
# Epoch 981/1000: Test accuracy: 0.692
# Epoch 982/1000: Test accuracy: 0.688
# Epoch 983/1000: Test accuracy: 0.693
# Epoch 984/1000: Test accuracy: 0.7
# Epoch 985/1000: Test accuracy: 0.687
# Epoch 986/1000: Test accuracy: 0.697
# Epoch 987/1000: Test accuracy: 0.691
# Epoch 988/1000: Test accuracy: 0.69
# Epoch 989/1000: Test accuracy: 0.691
# Epoch 990/1000: Test accuracy: 0.693
# Epoch 991/1000: Test accuracy: 0.692
# Epoch 992/1000: Test accuracy: 0.688
# Epoch 993/1000: Test accuracy: 0.684
# Epoch 994/1000: Test accuracy: 0.698
# Epoch 995/1000: Test accuracy: 0.698
# Epoch 996/1000: Test accuracy: 0.692
# Epoch 997/1000: Test accuracy: 0.689
# Epoch 998/1000: Test accuracy: 0.698
# Epoch 999/1000: Test accuracy: 0.69
